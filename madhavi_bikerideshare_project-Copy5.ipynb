# %%
import time
import pandas as pd
import numpy as np

CITY_DATA = { 'chicago': r'C:\Users\6015381\Downloads\chicago.csv',
              'new york city': r'C:\Users\6015381\Downloads\new_york_city.csv',
              'washington': r'C:\Users\6015381\Downloads\washington.csv' }



MONTH = { 'january': 1,'february': 2,'march': 3,'april': 4,'may': 5,'june': 6 }
DAYS_LIST = { 'monday': 0,'tuesday': 1,'wednesday': 2,'thursday': 3,'friday': 4,'saturday': 5,'sunday': 6 }

def get_filters():
    """
    Asks user to specify a city, month, and day to analyze. 

    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print('Hello! Let\'s explore some US bikeshare data!')
    
    day=''
    month=''
        
    
    city = input('Which city you would like to analyze? chicago, new york city or washington?:')
    while city.lower() not in CITY_DATA:
        print('That is an invalid city, please choose between chicago, new york or washington!:')
        city = input('Which city you would like to analyze? chicago, new york city or washington?:')
    
    print('your choice was: ', city)
    inputvar = input('do you want to filter by month or day or both or none:')
    while inputvar not in ['month', 'day', 'both', 'none']:
        print('That is an invalid selection, please choose between month, day or both:')
        inputvar = input('do you want by month or day or both or none:')
    while 1:
        if inputvar=='month':
            print('Please enter the month:')
            month = input('january, february, march, april, may, june: ')
            print()
            if month not in MONTH:
                print('That is an invalid selection, please enter valid month: ')
                continue
            month = MONTH[month.lower()]
            print('month in if loop: {0}' .format(month))
            day='all'
        elif inputvar =='day':
            print('Please enter the day: ')
            day = input('monday, tuesday, wednesday, thursday, friday, saturday, sunday: ')
            print()
            if day not in DAYS_LIST:
                print('That is an invalid selection, please enter valid day: ')
                continue
            day = DAYS_LIST[day.lower()]
            month='all'
        elif inputvar =='both':
            print('Please enter the month')
            month = input('january, february, march, april, may, june')
            print()
            if month not in MONTH:
                print('That is an invalid selection, please enter valid month:')
                continue
            month = MONTH[month.lower()]
            print('please enter day of the week?')
            day = input('monday, tuesday, wednesday, thursday, friday, saturday, sunday: ')
            print()
            if day not in DAYS_LIST:
                print('That is an invalid selection, please enter valid day:')
                continue
            day = DAYS_LIST[day.lower()]
        elif inputvar=='none':
            month = 'all'
            day = 'all'
        else:
            print('Not a valid input, please try again')
            continue
        break
    

    return city, month, day 

def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.

    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """

    # load data file into a dataframe
    df = pd.read_csv(CITY_DATA[city])

    # convert the Start Time column to datetime
    df['day_of_week'] = pd.to_datetime(df['Start Time']).dt.dayofweek
    df['month'] = pd.to_datetime(df['Start Time']).dt.month
    #print(df.head(5))
    if day != 'all':
        df = df[df['day_of_week'] == day]
    if month != 'all':
        df = df[df['month'] == month]
    
    return df

def time_stats(df):
    """Displays statistics on the most frequent times of travel."""

    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()
    #print('very important month data in time stats: {0}' .format(df['month'].mode()[0]))
    df['day_of_week'] = pd.to_datetime(df['Start Time']).dt.dayofweek
    df['month'] = pd.to_datetime(df['Start Time']).dt.month
    
    comm_mon = df['month'].mode()[0]
    #print('common month : {0}'.format(comm_mon))
    print('-'*40)
    for mon in MONTH:
        if MONTH[mon]==comm_mon:
            comm_mon = mon.title()
    
    print('Most common month is : {0}' .format(comm_mon))
    
    
    
     # TO DO: display the most common day of week
   
       
    most_freq_day = df['day_of_week'].mode()[0]
    #print('common day of week value: {0}' .format(most_freq_day))
    for num in DAYS_LIST:
        if DAYS_LIST[num]==most_freq_day:
            most_freq_day = num.title()
    print('The most common day of week for travel is {}'.format(most_freq_day))
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

    

def station_stats(df):
    """Displays statistics on the most popular stations and trip."""

    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station
    print("Most commonly used start station is : {0}" .format(df['Start Station'].mode()))


    # TO DO: display most commonly used end station
    print("Most commonly used start station is : {0}" .format(df['End Station'].mode()))

    # TO DO: display most frequent combination of start station and end station trip
    print("Most frequent combination of start and end station trip is :\n {0}" .format(df.groupby(['Start Station', 'End Station']).size().nlargest(1)))

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""

    print('\nCalculating Trip Duration...\n')
    start_time = time.time()

    # TO DO: display total travel time
    print("Total Trip Duration in seconds is :{0}" .format((df['Trip Duration'].sum()/60)))


    # TO DO: display mean travel time
    print("mean travel time in seconds is : {0}" .format(df['Trip Duration'].mean()/60))

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def user_stats(df):
    """Displays statistics on bikeshare users."""

    print('\nCalculating User Stats...\n')
    start_time = time.time()
    try:
        if ('Gender' not in df):
            print('Gender data not available for this city')
        else:
            print("counts of gender is:\n {0}" .format(df['Gender'].value_counts()))
        print('\n')
        # TO DO: Display counts of user types
        print("count of user types is : {0}" .format(df['User Type'].nunique()))
        print("counts for each user type is :\n {0}" .format(df['User Type'].value_counts()))
        
    except Exception as e:
        print('An error occured with User Types: {}'.format(e))

        # TO DO: Display counts of gender
        #if city.lower() != 'washington':
        #try:
            #print("counts of gender is: {0}" .format(df['Gender'].value_counts()))


        # TO DO: Display earliest, most recent, and most common year of birth
        print("earliest birth year in the series is : {0}" .format(int(min(df['Birth Year']))))
        print("most recent birth year in the data is : {0}" .format(int(max(df['Birth Year']))))
        print("most common birth year in the data is : {0}" .format(int(df.mode()['Birth Year'][0])))
    except Exception as e:
        print('An error occurred with Gender and Birth year statistics, the attribute may not exist in the source data: {}'.format(e))
    

    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)


def main():
    while True:
        city, month, day = get_filters()
        df = load_data(city, month, day)

        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df)

        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break


if __name__ == "__main__":
	main()
# Out:
# Hello! Let's explore some US bikeshare data!
# Which city you would like to analyze? chicago, new york city or washington?:chicago
# your choice was:  chicago
# do you want to filter by month or day or both or none:none
#
# Calculating The Most Frequent Times of Travel...
#
# ----------------------------------------
# Most common month is : June
# The most common day of week for travel is Tuesday
#
# This took 0.3445420265197754 seconds.
# ----------------------------------------
#
# Calculating The Most Popular Stations and Trip...
#
# Most commonly used start station is : 0    Streeter Dr & Grand Ave
# dtype: object
# Most commonly used start station is : 0    Streeter Dr & Grand Ave
# dtype: object
# Most frequent combination of start and end station trip is :
#  Start Station              End Station
# Lake Shore Dr & Monroe St  Streeter Dr & Grand Ave    854
# dtype: int64
#
# This took 0.11568284034729004 seconds.
# ----------------------------------------
#
# ...
